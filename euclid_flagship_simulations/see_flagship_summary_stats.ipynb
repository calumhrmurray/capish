# %%
import pickle
import glob
import sys, copy
from astropy.table import Table
import numpy as np
import pyccl as ccl
import glob
import matplotlib.pyplot as plt
def load(filename, **kwargs):
    with open(filename, 'rb') as fin:
        return pickle.load(fin, **kwargs)
import itertools

# %%
plt.figure(figsize=(12,4),dpi=100)
plt.subplot(121)
color = ['r','b','g']


file = ['flagship_summary_stat_DES_MoR_no_Mwl_scatter_Gamma1_gaussian_lensing_variable_Mwl.npy',
       'flagship_summary_stat_DES_MoR_Mwl_scatter_model_Gamma1_gaussian_lensing_variable_Mwl.npy',
       'flagship_summary_stat_DES_MoR_Mwl_scatter_model_Gamma0.7_gaussian_lensing_variable_Mwl.npy']
for i, f in enumerate(file): 
    print(f)
    data = np.load(f, allow_pickle=True).item()
    print(data.keys())
    plt.plot(data['mean_log10m200b'][:,0], ':', color=color[i],label = f.split('MoR_')[1], lw=4)

plt.legend(fontsize=8)
plt.xlabel('rich index')
plt.ylabel('mean log10M')
plt.xlim(-0.1, 4.1)
plt.grid(True)
plt.ylim(14, 15.9)

plt.subplot(122)
color = ['r','b','g']
file = ['flagship_like_summary_stat_DES_MoR_no_Mwl_scatter_model_Gamma1_gaussian_lensing_variable_log10Mwl.npy',
       'flagship_like_summary_stat_DES_MoR_Mwl_scatter_model_Gamma1_gaussian_lensing_variable_log10Mwl.npy',
       'flagship_like_summary_stat_DES_MoR_Mwl_scatter_model_Gamma0.7_gaussian_lensing_variable_log10Mwl.npy']
for i, f in enumerate(file): 
    print(f)
    data = np.load(f, allow_pickle=True).item()
    print(data.keys())
    plt.plot(data['mean_log10m200b'][:,0], color=color[i],label = f.split('MoR_')[1], lw=1)


file = ['flagship_like_summary_stat_DES_MoR_no_Mwl_scatter_Gamma1_gaussian_lensing_variable_Mwl.npy',
       'flagship_like_summary_stat_DES_MoR_Mwl_scatter_model_Gamma1_gaussian_lensing_variable_Mwl.npy',
       'flagship_like_summary_stat_DES_MoR_Mwl_scatter_model_Gamma0.7_gaussian_lensing_variable_Mwl.npy']
for i, f in enumerate(file): 
    print(f)
    data = np.load(f, allow_pickle=True).item()
    print(data.keys())
    plt.plot(data['mean_log10m200b'][:,0], ':', color=color[i],label = f.split('MoR_')[1], lw=4)

plt.legend(fontsize=8)
plt.xlabel('rich index')
plt.ylabel('mean log10M')
plt.xlim(-0.1, 4.1)
plt.grid(True)
plt.ylim(14, 15.9)
plt.savefig(f'sims_mass.png', dpi = 300, bbox_inches='tight',)
# Out:
# flagship_summary_stat_DES_MoR_no_Mwl_scatter_Gamma1_gaussian_lensing_variable_Mwl.npy
# dict_keys(['count_with_m200b_def', 'mean_log10m200b', 'count_with_m200c_def', 'mean_log10m200c'])
# flagship_summary_stat_DES_MoR_Mwl_scatter_model_Gamma1_gaussian_lensing_variable_Mwl.npy
# dict_keys(['count_with_m200b_def', 'mean_log10m200b', 'count_with_m200c_def', 'mean_log10m200c'])
# flagship_summary_stat_DES_MoR_Mwl_scatter_model_Gamma0.7_gaussian_lensing_variable_Mwl.npy
# dict_keys(['count_with_m200b_def', 'mean_log10m200b', 'count_with_m200c_def', 'mean_log10m200c'])
# flagship_like_summary_stat_DES_MoR_no_Mwl_scatter_model_Gamma1_gaussian_lensing_variable_log10Mwl.npy
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[118], line 29
#      27 for i, f in enumerate(file):
#      28     print(f)
# ---> 29     data = np.load(f, allow_pickle=True).item()
#      30     print(data.keys())
#      31     plt.plot(data['mean_log10m200b'][:,0], color=color[i],label = f.split('MoR_')[1], lw=1)
#
# File ~/.conda/envs/myenv/lib/python3.10/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flagship_like_summary_stat_DES_MoR_no_Mwl_scatter_model_Gamma1_gaussian_lensing_variable_log10Mwl.npy'

# %%
plt.figure(dpi=100)
color = ['r','b','g']
file = ['flagship_summary_stat_DES_MoR_Mwl_scatter_Gamma1_gaussian_lensing_variable_Mwl.npy',
       'flagship_like_summary_stat_DES_MoR_Mwl_scatter_Gamma1_gaussian_lensing_variable_Mwl.npy',
       ]
for i, f in enumerate(file): 
    print(f)
    data = np.load(f, allow_pickle=True).item()
    
    plt.plot(data['count_with_m200b_def'], color=color[i], lw=1)
plt.yscale('log')
plt.plot([], [], label = 'flagship + MoR')
plt.plot([], [], label = 'flagship-like')

plt.xlabel('rich index')
plt.ylabel('Count')
plt.legend(fontsize=8)
plt.xlabel('rich index')
plt.ylabel('COUNT')
plt.xlim(-0.1, 4.1)
plt.grid(True)
plt.ylim(1, 100000)
plt.savefig(f'sims_count.png', dpi = 300, bbox_inches='tight',)
# Out:
# flagship_summary_stat_DES_MoR_Mwl_scatter_Gamma1_gaussian_lensing_variable_Mwl.npy
# flagship_like_summary_stat_DES_MoR_Mwl_scatter_Gamma1_gaussian_lensing_variable_Mwl.npy
