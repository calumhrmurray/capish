# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('/pbs/home/c/cmurray/cluster_likelihood/')
import modules.simulation as simulation
import pyccl as ccl
import modules.summary_statistics as ss

# %% [markdown]
# Run a simple and small SBI thing.

# %%
simulator = simulation.UniverseSimulator( ss.counts_and_mean_mass ,  config_path = '/pbs/home/c/cmurray/cluster_likelihood/config/capish.ini' )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 simulator = simulation.UniverseSimulator( ss.counts_and_mean_mass ,  config_path = '/pbs/home/c/cmurray/cluster_likelihood/config/capish.ini' )
#
# AttributeError: module 'modules.summary_statistics' has no attribute 'counts_and_mean_mass'

# %%
ss.cou
