# %% [markdown]
# Var( < Lambda | M >{stacked} ) > Var( < Lambda | M{unbinned} > )
#
# That's before adding the fact that the stacked approach has little information of the variance between different observables and the mass.

# %%
import numpy as np

# %%
np.power(10, -(24-23.9)/2.5)
# Out:
# 0.9120108393559085

# %%
np.power(10., 0.4 * ( -48.6 - 23.9 ) )
# Out:
# 1e-29

# %%
-0.4 * ( -48.6 - 23.9 )
# Out:
# 29.0
