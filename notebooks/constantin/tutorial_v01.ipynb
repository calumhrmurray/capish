# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../../')
import modules.simulation as simulation
import pyccl as ccl

# %%
simulator = simulation.UniverseSimulator( None , '../../config/capish.ini')

# %%
cosmo = ccl.Cosmology( Omega_c = 0.25, Omega_b = 0.05, h = 0.7 , sigma8 = 0.8, n_s= 0.96)

# %%
# %time
Nth, log10mass, redshift = simulator.halo_catalogue_class.get_halo_catalogue(cosmo, return_Nth=True)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 11.7 µs

# %%
plt.hist2d(log10mass, redshift, bins=[30, 20], cmin=1, cmap='gist_rainbow')
plt.colorbar()
plt.xlabel('log10M')
plt.ylabel('z')
plt.show()

# %%
plt.imshow(Nth['N_th'].T, origin='lower', aspect='auto', cmap='gist_rainbow')
plt.colorbar()
