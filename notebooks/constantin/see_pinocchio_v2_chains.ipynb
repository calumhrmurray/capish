# %%
# %load_ext autoreload

# %autoreload 2
import numpy as np
import corner, sys
import getdist
from getdist import plots, MCSamples
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('../../pinocchio/')
import pinocchio_mass_richness_relation
#plt.switch_backend("Qt5Agg")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
names = ['1', '2', '3', '4', '5', '6',]
labels = [r'\ln \lambda_0', r'\mu_z', r'\mu_m', r'\sigma_{\ln \lambda, 0}', r'\Omega_m', r'\sigma_8']
settings={'mult_bias_correction_order':0,'smooth_scale_2D':4, 'smooth_scale_1D':4, 'boundary_correction_order':0}

# %%
n_cut=20000
where = '/pbs/throng/lsst/users/cpayerne/capish/chains/'
t = np.load(where + f'pinochio_v2_chain_NxMwl_fit_cosmo_num_params_rm_rel_0_log_normal_poisson_scatter_sigma_lnMwl=0.25_with_Poisson_count_likelihood.pkl', allow_pickle = True)
NxMwl_fix_cosmo = MCSamples(samples=t['flat_chains'][n_cut:],names = [names[-2], names[-1]], 
                    labels = [labels[-2], labels[-1]], 
                     settings=settings, 
                     label='NxWL - fixed_cosmology')
# Out:
# Removed no burn in

# %%
markers = {'5':0.30711, '6':.8288 }

# %%
g = plots.get_subplot_plotter(subplot_size=1.)
g.settings.lab_fontsize = 20
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 13
marker_args = {'lw':0.75, 'markersize':0.75, 'ls':'--','color':'b'}
range = {'1':(3.15,3.3) }
g.triangle_plot(
                [NxMwl_fix_cosmo], 
                filled=[False, False, True, False, False], 
                contour_colors = ['b', 'r', 'g', 'k', 'r', 'k' ], 
                contour_ls=['-','-','-', '-', '-'],
                contour_lws=[0.7,1.2,1,1,2],
                legend_fontsize = 10,
                #param_limits = range,
                markers=markers,
                fine_bins = 5,  
                marker_args = marker_args)
#plt.savefig(f'/pbs/throng/lsst/users/cpayerne/capish/figures/pinocchio_1000_mocks.png', dpi = 300)

# %%
n_cut=20000
where = '/pbs/throng/lsst/users/cpayerne/capish/chains/'
t = np.load(where + f'pinochio_v2_chain_NxMwl_fit_cosmo_num_params_rm_rel_4_log_normal_poisson_scatter_sigma_lnMwl=0.25_with_Poisson_count_likelihood.pkl', allow_pickle = True)
NxMwl_fix_cosmo = MCSamples(samples=t['flat_chains'][n_cut:],names = names, 
                    labels = labels, 
                     settings=settings, 
                     label='NxWL - fixed_cosmology')
# Out:
# Removed no burn in

# %%
markers = {}
markers['1'] = pinocchio_mass_richness_relation.proxy_mu0
markers['2'] = pinocchio_mass_richness_relation.proxy_muz
markers['3'] = pinocchio_mass_richness_relation.proxy_mulog10m
markers['4'] = pinocchio_mass_richness_relation.proxy_sigmalog10m
markers['5'] = 0.30711
markers['6'] = .8288
print(markers)
# Out:
# {'1': 3.4, '2': 0.0, '3': 1.65, '4': 0, '5': 0.30711, '6': 0.8288}

# %%
g = plots.get_subplot_plotter(subplot_size=1.)
g.settings.lab_fontsize = 20
g.settings.legend_fontsize = 15
g.settings.axes_fontsize = 13
marker_args = {'lw':0.75, 'markersize':0.75, 'ls':'--','color':'b'}
range = {'1':(3.15,3.3) }
g.triangle_plot(
                [NxMwl_fix_cosmo], 
                filled=[False, False, True, False, False], 
                contour_colors = ['b', 'r', 'g', 'k', 'r', 'k' ], 
                contour_ls=['-','-','-', '-', '-'],
                contour_lws=[0.7,1.2,1,1,2],
                legend_fontsize = 10,
                #param_limits = range,
                markers=markers,
                fine_bins = 5,  
                marker_args = marker_args)
#plt.savefig(f'/pbs/throng/lsst/users/cpayerne/capish/figures/pinocchio_1000_mocks.png', dpi = 300)
