# %%
import numpy as np
import pickle, emcee
import matplotlib.pyplot as plt
def load(filename, **kwargs):
    with open(filename, 'rb') as fin:
        return pickle.load(fin, **kwargs)

# %%
import emcee

filename = "chains_count_only.h5"
backend = emcee.backends.HDFBackend(filename)

# Get the chain
chain = backend.get_chain(discard=0, thin=1, flat=True)         # shape: (nsteps, nwalkers, ndim)
print(chain.shape)
log_prob = backend.get_log_prob()   # log-probabilities
blobs = backend.get_blobs()         # optional extra data
# Out:
# (1650, 5)

# %%
plt.scatter(chain[:,0],chain[:,1], marker='o', s=4)
